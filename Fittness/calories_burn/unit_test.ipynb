# %%
import unittest
import records as re

# %%
class TestBmr(unittest.TestCase)：
    def setUp(self):
        print('Set up')
        
    def tearDown(self):
        print('Tear Down')
    
    def test_Bmr(self):
        self.assertEuqal()
